# %% [markdown]
# <a href="https://colab.research.google.com/github/yallavaibhav/Comic-AudioBooks/blob/vaibhav/Contours_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import linraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read image
gray_scale = cv2.imread('/content/Screenshot 2023-02-12 233231.png', 0)

#display
plt.figure(figsize=[10,10])
plt.imshow(gray_scale, cmap="gray");plt.title("original")
# Out:
# Text(0.5, 1.0, 'original')

# %%
#Find contours of the image
contours, hirechay = cv2.findContours(gray_scale,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#Number of contours found
print(len(contours))
# Out:
# 25

# %%
#Draw Contours
origninal = cv2.imread('/content/Screenshot 2023-02-12 233231.png')
con_img = cv2.drawContours(origninal,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness

plt.imshow(con_img)

# %% [markdown]
# Preprocessing:
# We need to preprocess the image befpre using contours to get a good result.
#
# 1. Threshold based preprocessing
# 2. Canny Edge Detection

# %%
# Original image
img_2 = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
plt.imshow(img_2[:,:,::-1])

# %%
#Make a copy of source image
img2_copy = img_2.copy()
gray = cv2.cvtColor(img2_copy,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap = 'gray'); plt.title('Gray sclae')
# Out:
# Text(0.5, 1.0, 'Gray sclae')

# %%
#To invert the image
C = cv2.bitwise_not(gray)
plt.imshow(gray_inverted,cmap = 'gray')

# %%
#Find contours of the image
contours, hirechay = cv2.findContours(gray,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_inv_temp = cv2.drawContours(img_2,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_inv_temp)

# %%
#Thresholding
_,binary = cv2.threshold(gray,252,255,cv2.THRESH_BINARY)
plt.imshow(binary, cmap='gray')

# %%
#Find contours of the image
Thresh_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
contours1, hirechay1 = cv2.findContours(binary,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_thresh = cv2.drawContours(Thresh_original,contours1, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_thresh)

# %%
#Find contours of the image
Thresh_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
contours, hirechay = cv2.findContours(binary,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_thresh = cv2.drawContours(Thresh_original,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_thresh)

# %%
#Canny edge Detection

# %%
img3 = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
# Blur the images
blurred_images = cv2.GaussianBlur(img3,(5,5),0)
# Apply canny edge detection
edges = cv2.Canny(blurred_images,100,100)
plt.imshow(edges,cmap = 'gray')

# %%
Canny_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
contours, hirechay = cv2.findContours(edges,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_canny = cv2.drawContours(Canny_original,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_canny)

# %%
edges = cv2.Canny(binary,100,100)
plt.imshow(edges,cmap = 'gray')

# %%
Canny_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
contours, hirechay = cv2.findContours(edges,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_canny_bin = cv2.drawContours(Canny_original,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_canny_bin)

# %%
img3 = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
# Blur the images
blurred_images = cv2.GaussianBlur(binary,(5,5),0)
# Apply canny edge detection
edges = cv2.Canny(blurred_images,100,100)
plt.imshow(edges,cmap = 'gray')

# %%
Canny_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
contours, hirechay = cv2.findContours(edges,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
con_canny_blur_binary = cv2.drawContours(Canny_original,contours, -1,(0,255,0),3) #-1 is to detect all contours, (255,255,255)=>green line, 3=> thickness
plt.imshow(con_canny_blur_binary)

# %%
Hull_original = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
# Convex Hull
cnt = contours1[13]
hull = cv2.convexHull(cnt)
con_hull = cv2.drawContours(Hull_original,[hull],0,(0,0,220),3)
plt.imshow(con_hull)

#Here we need are getting many hulls for unwanted things. There are in total 14 contours detected. In this, 3 and 13th contours are only
# important. We need to consider the area. Based on largest

# %%
Hull_original1 = cv2.imread('/content/Screenshot 2023-02-12 233052.png')
cnt = contours1[3]
hull = cv2.convexHull(cnt)
con_hull = cv2.drawContours(Hull_original,[hull],0,(0,0,220),3)
plt.imshow(con_hull)

# %%
cnt = contours1[5]
hull = cv2.convexHull(cnt)
con_hull = cv2.drawContours(Hull_original,[hull],0,(0,0,220),3)
plt.imshow(con_hull)
