# %% [markdown]
# <a href="https://colab.research.google.com/github/yallavaibhav/Comic-AudioBooks/blob/vaibhav/Copy_of_Marvel_Yolov5_Panels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install tensorflow
# pip install tensorboard
# pip install torch

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.7/107.7 GB disk)

# %%
# !unzip -q ../Marvel_venom.v1i.darknet.zip -d ../

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 20 --data custom.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# ...

# %%
 # Testing with a new image
# !python detect.py --source /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg: 640x640 7 Panelss, 507.4ms
# Speed: 4.3ms pre-process, 507.4ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# Croping the images
# !python detect.py --save-crop --source /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg: 640x640 7 Panelss, 396.6ms
# Speed: 3.4ms pre-process, 396.6ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# Getting values only

# !python detect.py --save-txt --source /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg: 640x640 7 Panelss, 659.7ms
# Speed: 4.3ms pre-process, 659.7ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# Getting values and detection

# !python /content/yolov5/detect.py --save-crop --save-txt --source /content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0310_jpg.rf.f9cfa15872fd0532e84bee8e36763493.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Marvel_venom.v1i.darknet/images/test/Venomnibus-v01-0310_jpg.rf.f9cfa15872fd0532e84bee8e36763493.jpg, data=../../../../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../../../../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
# 0 0.88125 0.5625 0.175 0.271875
# 0 0.351562 0.217187 0.703125 0.303125
# 0 0.610937 0.821875 0.778125 0.35625
# 0 0.107031 0.838281 0.173438 0.285937
# 0 0.817969 0.51875 0.285937 0.35625
# 0 0.504687 0.526563 0.303125 0.34375
# 0 0.200781 0.525781 0.307813 0.370313

# %%
# 0 0.88125 0.5625 0.175 0.271875
# 0 0.351562 0.217187 0.703125 0.303125
# 0 0.610937 0.821875 0.778125 0.35625
# 0 0.107031 0.838281 0.173438 0.285937
# 0 0.817969 0.51875 0.285937 0.35625
# 0 0.504687 0.526563 0.303125 0.34375
# 0 0.200781 0.525781 0.307813 0.370313

#extract the elements only two values
# First sort the y-axis, then we will sort the x-axis - Done
# get the correct order
# try to extract as pics with this order

# %%
data = [[0.88125, 0.5625],
     [0.351562, 0.217187],
     [0.610937, 0.821875],
     [0.107031, 0.838281],
     [0.817969, 0.51875],
     [0.504687, 0.526563],
     [0.200781, 0.525781]]

# %%
data.sort(key=lambda x:x[1])

# %%
data
# Out:
# [[0.351562, 0.217187],
#  [0.817969, 0.51875],
#  [0.200781, 0.525781],
#  [0.504687, 0.526563],
#  [0.88125, 0.5625],
#  [0.610937, 0.821875],
#  [0.107031, 0.838281]]

# %%
# x = []
# y = []
# k = 0
# for i in range(len(data)):
#   if data[i][1] < data[k][1]+0.2:
#     x.append(data[i])
#     print(x)
#   else:
#     x.sort()
#     y.append(x)
#     print(y)
#     x = []
#     print(x)
#     x.append(data[i])
#     k=i
# x.sort()
# y.append(x)
# Out:
# [[0.351562, 0.217187]]
# [[[0.351562, 0.217187]]]
# []
# [[0.817969, 0.51875], [0.200781, 0.525781]]
# [[0.817969, 0.51875], [0.200781, 0.525781], [0.504687, 0.526563]]
# [[0.817969, 0.51875], [0.200781, 0.525781], [0.504687, 0.526563], [0.88125, 0.5625]]
# [[[0.351562, 0.217187]], [[0.200781, 0.525781], [0.504687, 0.526563], [0.817969, 0.51875], [0.88125, 0.5625]]]
# []
# [[0.610937, 0.821875], [0.107031, 0.838281]]

# %%
# y
# Out:
# [[[0.351562, 0.217187]],
#  [[0.200781, 0.525781],
#   [0.504687, 0.526563],
#   [0.817969, 0.51875],
#   [0.88125, 0.5625]],
#  [[0.107031, 0.838281], [0.610937, 0.821875]]]

# %%
#Test
x = []
y = []
k = 0
for i in range(len(data)):
  if data[i][1] < data[k][1]+0.2:
    x.append(data[i])
    print(x)
  else:
    x.sort()
    for j in range(len(x)):
      y.append(x[j])
    print(y)
    x = []
    print(x)
    x.append(data[i])
    k=i
x.sort()
for p in range(len(x)):
  y.append(x[p])
# Out:
# [[0.351562, 0.217187]]
# [[0.351562, 0.217187]]
# []
# [[0.817969, 0.51875], [0.200781, 0.525781]]
# [[0.817969, 0.51875], [0.200781, 0.525781], [0.504687, 0.526563]]
# [[0.817969, 0.51875], [0.200781, 0.525781], [0.504687, 0.526563], [0.88125, 0.5625]]
# [[0.351562, 0.217187], [0.200781, 0.525781], [0.504687, 0.526563], [0.817969, 0.51875], [0.88125, 0.5625]]
# []
# [[0.610937, 0.821875], [0.107031, 0.838281]]

# %%
y
# z = [[0.817969, 0.51875], [0.200781, 0.525781]]
# z[0]
# Out:
# [[0.351562, 0.217187],
#  [0.200781, 0.525781],
#  [0.504687, 0.526563],
#  [0.817969, 0.51875],
#  [0.88125, 0.5625],
#  [0.107031, 0.838281],
#  [0.610937, 0.821875]]

# %% [markdown]
# New thing related to detecting the sorted things using opencv

# %%
# 0 0.88125 0.5625 0.175 0.271875
# 0 0.351562 0.217187 0.703125 0.303125
# 0 0.610937 0.821875 0.778125 0.35625
# 0 0.107031 0.838281 0.173438 0.285937
# 0 0.817969 0.51875 0.285937 0.35625
# 0 0.504687 0.526563 0.303125 0.34375
# 0 0.200781 0.525781 0.307813 0.370313

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/Venomnibus-v01-0020_jpg.rf.605ff5b0ece83f3c5afe743f67a6a654.jpg')
plt.imshow(img)

# %%
cv2.rectangle(img,(0.88125,0.5625),(0.175,0.271875),(255,0,0),5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-1617b56cc65f> in <module>
# ----> 1 cv2.rectangle(img,(0.88125,0.5625),(0.175,0.271875),(255,0,0),5)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'rec'. Expected sequence length 4, got 2
# >  - Can't parse 'rec'. Expected sequence length 4, got 2

# %%
# %cd /content/yolov5/runs/detect/exp6/labels/*
# Out:
# [Errno 2] No such file or directory: '/content/yolov5/runs/detect/exp6/labels/*'
# /content/yolov5/runs/detect/exp6/labels
